# %%
import pandas as pd
import os

# handles a list of files on the filesystem with names matching a pattern
import glob

# %%
# access files in folder "data"
os.listdir('data')
# Out:
# ['data-201710-12.csv',
#  'data-201707-09.csv',
#  'data-201801-03.csv',
#  'data-201901-03.csv',
#  'data-201704-06.csv',
#  'data-201701-03.csv',
#  'data-201804-06.csv',
#  'data-201810-12.csv',
#  'data-201807-09.csv']

# %%
path = "data"
filelist = glob.glob(path + "/data*.csv")
filelist
# Out:
# ['data/data-201710-12.csv',
#  'data/data-201707-09.csv',
#  'data/data-201801-03.csv',
#  'data/data-201901-03.csv',
#  'data/data-201704-06.csv',
#  'data/data-201701-03.csv',
#  'data/data-201804-06.csv',
#  'data/data-201810-12.csv',
#  'data/data-201807-09.csv']

# %%
list = []
for f in filelist:
    df = (pd.read_csv(f))
    list.append(df)

# %%
concat_list = pd.concat(list, axis = 0, ignore_index = True)
concat_list
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0     10/1/17                                              55503
# 1     10/2/17                                              65509
# 2     10/3/17                                              69105
# 3     10/4/17                                              71453
# 4     10/5/17                                              70173
# 5     10/6/17                                              70249
# 6     10/7/17                                              63630
# 7     10/8/17                                              41039
# 8     10/9/17                                              38390
# 9    10/10/17                                              74117
# 10   10/11/17                                              63587
# 11   10/12/17                                              61244
# 12   10/13/17                                              67016
# ...

# %%
concat_list.count()
# Out:
# Date                                                  803
# Trips over the past 24-hours (midnight to 11:59pm)    803
# Miles traveled today (midnight to 11:59 pm)           803
# Total Annual Members (All Time)                       803
# 24-Hour Passes Purchased (midnight to 11:59 pm)       803
# 3-Day Passes Purchased (midnight to 11:59 pm)         803
# dtype: int64

# %%
concat_list.to_csv("data/ridership_membership_data.csv")
